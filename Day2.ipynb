# %% [markdown]
# <a href="https://colab.research.google.com/github/kalpesh5536/IN226014802_NLP/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk

# %%
import re
import string
import nltk

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stop_words=set(stopwords.words('english'))
lemmatizer=WordNetLemmatizer()

# %%
text='I love this movie!!!'
print(f'Original text:{text}')
# Out:
# Original text:I love this movie!!!

# %%
def preprocess_text(text):
  #1 Lowercasing
  text=text.lower()

  #2 remove punctuations
  text=text.translate(str.maketrans('','',string.punctuation))

  #3 remove special character/emojis
  text=re.sub(r'[^\w\s]','',text) # \w\s - anything except words and space, replace all other to underscore, it will give only text, spaces and digits

 #4 Tokenization
  tokens= text.split()

 #5 stopwords removal
  tokens=[word for word in tokens if word not in stop_words]

#6 lemmatization
  tokens=[lemmatizer.lemmatize(word)for word in tokens]

  return tokens

# %%
processed= preprocess_text(text)
print(f'Processed Text:{processed}')
# Out:
# Processed Text:['love', 'movie']

# %%
text=['I Hate this movie!!','This course is very helpful','worst experience Ever!!!', 'I am learning NLP and it is amazing']

# %%
lst = []
for i in text:
  lst.append(i)
  x=i.lower()
  print(x)
# Out:
# i hate this movie!!
# this course is very helpful
# worst experience ever!!!
# i am learning nlp and it is amazing

# %%
for i in text:
  print(f'original:{i}')
# Out:
# original:I Hate this movie!!
# original:This course is very helpful
# original:worst experience Ever!!!
# original:I am learning NLP and it is amazing

# %%
for i in text:
  print(f'processed:{preprocess_text(i)}')
# Out:
# processed:['hate', 'movie']
# processed:['course', 'helpful']
# processed:['worst', 'experience', 'ever']
# processed:['learning', 'nlp', 'amazing']

# %%
def tokens_to_sentence(tokens):
  return ' '.join(tokens)

# %%
example=preprocess_text('This course is Amazing!!')
print(example)
# Out:
# ['course', 'amazing']

# %%
tokens_to_sentence(example)
# Out:
# 'course amazing'
